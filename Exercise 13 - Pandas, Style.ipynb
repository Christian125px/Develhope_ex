# %% [markdown]
# # Exercise 13 - Pandas, Style

# %% [markdown]
# Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight dataframe’s specific columns with different colors.

# %%
# Importing Pandas and Numpy
import pandas as pd
import numpy as np

# %%
# Creating a df of random values with 10 rows and 4 columns
data = np.random.rand(10, 4) # Creating a 10x4 array of random values
df = pd.DataFrame(data, columns=['Column1', 'Column2', 'Column3', 'Column4']) # Converting the array in a df

# Introducing some NaN values
df.iloc[2, 1] = np.nan
df.iloc[5, 2] = np.nan
df.iloc[7, 0] = np.nan

df
# Out:
#     Column1   Column2   Column3   Column4
# 0  0.618826  0.133461  0.980580  0.871786
# 1  0.502721  0.922348  0.541381  0.923306
# 2  0.829897       NaN  0.919783  0.036034
# 3  0.174772  0.389135  0.952143  0.300029
# 4  0.160468  0.886305  0.446394  0.907876
# 5  0.160230  0.661118       NaN  0.076487
# 6  0.696463  0.247399  0.039616  0.059944
# 7       NaN  0.907733  0.739884  0.898062
# 8  0.672582  0.528940  0.304446  0.997962
# 9  0.362189  0.470649  0.378245  0.979527

# %%
# Define a custom styling function to highlight columns containing at least one NaN
def highlight_nan_column(s):
    is_nan_column = s.isna().any()
    return ['background-color: red' if is_nan_column else '' for _ in s]

# Apply the styling function to the DataFrame columns
styled_df = df.style.apply(highlight_nan_column)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_bccf4_row0_col0, #T_bccf4_row0_col1, #T_bccf4_row0_col2, #T_bccf4_row1_col0, #T_bccf4_row1_col1, #T_bccf4_row1_col2, #T_bccf4_row2_col0, #T_bccf4_row2_col1, #T_bccf4_row2_col2, #T_bccf4_row3_col0, #T_bccf4_row3_col1, #T_bccf4_row3_col2, #T_bccf4_row4_col0, #T_bccf4_row4_col1, #T_bccf4_row4_col2, #T_bccf4_row5_col0, #T_bccf4_row5_col1, #T_bccf4_row5_col2, #T_bccf4_row6_col0, #T_bccf4_row6_col1, #T_bccf4_row6_col2, #T_bccf4_row7_col0, #T_bccf4_row7_col1, #T_bccf4_row7_col2, #T_bccf4_row8_col0, #T_bccf4_row8_col1, #T_bccf4_row8_col2, #T_bccf4_row9_col0, #T_bccf4_row9_col1, #T_bccf4_row9_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_bccf4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bccf4_level0_col0" class="col_heading level0 col0" >Column1</th>
#       <th id="T_bccf4_level0_col1" class="col_heading level0 col1" >Column2</th>
#       <th id="T_bccf4_level0_col2" class="col_heading level0 col2" >Column3</th>
#       <th id="T_bccf4_level0_col3" class="col_heading level0 col3" >Column4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bccf4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bccf4_row0_col0" class="data row0 col0" >0.618826</td>
#       <td id="T_bccf4_row0_col1" class="data row0 col1" >0.133461</td>
#       <td id="T_bccf4_row0_col2" class="data row0 col2" >0.980580</td>
#       <td id="T_bccf4_row0_col3" class="data row0 col3" >0.871786</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bccf4_row1_col0" class="data row1 col0" >0.502721</td>
#       <td id="T_bccf4_row1_col1" class="data row1 col1" >0.922348</td>
#       <td id="T_bccf4_row1_col2" class="data row1 col2" >0.541381</td>
#       <td id="T_bccf4_row1_col3" class="data row1 col3" >0.923306</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bccf4_row2_col0" class="data row2 col0" >0.829897</td>
#       <td id="T_bccf4_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_bccf4_row2_col2" class="data row2 col2" >0.919783</td>
#       <td id="T_bccf4_row2_col3" class="data row2 col3" >0.036034</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bccf4_row3_col0" class="data row3 col0" >0.174772</td>
#       <td id="T_bccf4_row3_col1" class="data row3 col1" >0.389135</td>
#       <td id="T_bccf4_row3_col2" class="data row3 col2" >0.952143</td>
#       <td id="T_bccf4_row3_col3" class="data row3 col3" >0.300029</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bccf4_row4_col0" class="data row4 col0" >0.160468</td>
#       <td id="T_bccf4_row4_col1" class="data row4 col1" >0.886305</td>
#       <td id="T_bccf4_row4_col2" class="data row4 col2" >0.446394</td>
#       <td id="T_bccf4_row4_col3" class="data row4 col3" >0.907876</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bccf4_row5_col0" class="data row5 col0" >0.160230</td>
#       <td id="T_bccf4_row5_col1" class="data row5 col1" >0.661118</td>
#       <td id="T_bccf4_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_bccf4_row5_col3" class="data row5 col3" >0.076487</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bccf4_row6_col0" class="data row6 col0" >0.696463</td>
#       <td id="T_bccf4_row6_col1" class="data row6 col1" >0.247399</td>
#       <td id="T_bccf4_row6_col2" class="data row6 col2" >0.039616</td>
#       <td id="T_bccf4_row6_col3" class="data row6 col3" >0.059944</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bccf4_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_bccf4_row7_col1" class="data row7 col1" >0.907733</td>
#       <td id="T_bccf4_row7_col2" class="data row7 col2" >0.739884</td>
#       <td id="T_bccf4_row7_col3" class="data row7 col3" >0.898062</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bccf4_row8_col0" class="data row8 col0" >0.672582</td>
#       <td id="T_bccf4_row8_col1" class="data row8 col1" >0.528940</td>
#       <td id="T_bccf4_row8_col2" class="data row8 col2" >0.304446</td>
#       <td id="T_bccf4_row8_col3" class="data row8 col3" >0.997962</td>
#     </tr>
#     <tr>
#       <th id="T_bccf4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bccf4_row9_col0" class="data row9 col0" >0.362189</td>
#       <td id="T_bccf4_row9_col1" class="data row9 col1" >0.470649</td>
#       <td id="T_bccf4_row9_col2" class="data row9 col2" >0.378245</td>
#       <td id="T_bccf4_row9_col3" class="data row9 col3" >0.979527</td>
#     </tr>
#   </tbody>
# </table>
